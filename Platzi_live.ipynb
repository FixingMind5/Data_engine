# %%
import pandas as pd

series_test = pd.Series([100, 200, 300])
series_test2 = pd.Series({1999: 48, 2000: 95, 2001: 34})

# series_test

series_test2
# Out:
# 1999    48
# 2000    95
# 2001    34
# dtype: int64

# %%
frame_test = pd.DataFrame({1999: [74, 38, 49],
                           2000: [56, 32, 20],
                           2001: [23, 54, 12]})

frame_test
# Out:
#    1999  2000  2001
# 0    74    56    23
# 1    38    32    54
# 2    49    20    12

# %%
frame_test2 = pd.DataFrame([[74, 38, 49],
                           [56, 32, 20],
                           [23, 54, 12]], columns=[1999, 2000, 2001])

# columns es para ponerles un "nombre" a la llave

frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    49
# 1    56    32    20
# 2    23    54    12

# %%
import pandas as pd

pd.options.display.max_rows = 10
el_universal = pd.read_csv('eluniversal_2019_01_12_articles.csv')

el_universal

# el_universal.tail() | para los últimos cinco
# el_universal.head() | para los primeros cinco
# Out:
#                                                   body  \
# 0    \n[email protected]\n\nTrabajadores contratado...
# 1    \nSi eres de las personas que se 'sube al tren...
# 2    \nLuego de publicar un tuit en su cuenta perso...
# 3    \n[email protected]\n\nLa Secretaría de Movili...
# 4    \nLa jefa de Gobierno, Claudia Sheinbaum, afir...
# ..                                                 ...
# 135  \nDiego Armando Maradona fue operado en la clí...
# 136  El gobierno de la Ciudad de México informó a t...
# 137  ¿Quieres viajar más, pero también ahorrar lo m...
# 138  Vas caminando tranquilamente en tu casa, desca...
# 139   7 % PULSO SOCIAL2 Esta mujer de ojos verdes f...
#
#                                                  title  \
# 0    INBA posterga incertidumbre de empleados con u...
# 1    Conoce las propiedades de la moringa, el super...
# 2    Si México, la tendencia en redes que desató Qu...
# 3    Pondrán a infractores de CDMX a pintar calles ...
# 4    Transporte público está garantizado, dice Shei...
# ..                                                 ...
# 135                   Operan a Diego Armando Maradona
# 136   Hay vacantes de promotores educativos de PILARES
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
#                                                    url
# 0    http://eluniversal.com.mx/cultura/inba-posterg...
# 1    http://eluniversal.com.mx/menu/conoce-las-prop...
# 2    http://eluniversal.com.mx/nacion/sociedad/si-m...
# 3    http://eluniversal.com.mx/metropoli/cdmx/pondr...
# 4    http://eluniversal.com.mx/metropoli/cdmx/trans...
# ..                                                 ...
# 135  http://eluniversal.com.mx/universal-deportes/f...
# 136  http://www.unioncdmx.mx/articulo/2019/01/10/ed...
# 137  http://www.viveusa.mx/compras/apps-y-herramien...
# 138  http://www.elbotiquin.mx/medicina-general/deci...
# 139  http://de10.com.mx/top-10/2019/01/12/kirstie-a...
#
# [140 rows x 3 columns]

# %%
# dictionary like

el_universal['title']
# Out:
# 0      ¿Cómo opera el huachicol dentro y fuera de Pemex?
# 1                Programas para buscar empleos en Canadá
# 2      "El Bronco" ofrece disculpas por incidente de ...
# 3      "Fernando Luján era profesional, disciplinado ...
# 4                                                    NaN
#                              ...
# 139    Cruz Azul ya aceptó propuesta por Marcone: Ang...
# 140       Nico Castillo ya está arreglado con el América
# 141                                                  NaN
# 142                                                  NaN
# 143                  Dieta del aguacate para perder peso
# Name: title, Length: 144, dtype: object

# %%
el_universal[['title', 'url']]
# Out:
#                                                  title  \
# 0    INBA posterga incertidumbre de empleados con u...
# 1    Conoce las propiedades de la moringa, el super...
# 2    Si México, la tendencia en redes que desató Qu...
# 3    Pondrán a infractores de CDMX a pintar calles ...
# 4    Transporte público está garantizado, dice Shei...
# ..                                                 ...
# 135                   Operan a Diego Armando Maradona
# 136   Hay vacantes de promotores educativos de PILARES
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
#                                                    url
# 0    http://eluniversal.com.mx/cultura/inba-posterg...
# 1    http://eluniversal.com.mx/menu/conoce-las-prop...
# 2    http://eluniversal.com.mx/nacion/sociedad/si-m...
# 3    http://eluniversal.com.mx/metropoli/cdmx/pondr...
# 4    http://eluniversal.com.mx/metropoli/cdmx/trans...
# ..                                                 ...
# 135  http://eluniversal.com.mx/universal-deportes/f...
# 136  http://www.unioncdmx.mx/articulo/2019/01/10/ed...
# 137  http://www.viveusa.mx/compras/apps-y-herramien...
# 138  http://www.elbotiquin.mx/medicina-general/deci...
# 139  http://de10.com.mx/top-10/2019/01/12/kirstie-a...
#
# [140 rows x 2 columns]

# %% [markdown]
# # Numpy like

# %%
el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \nCDMX.- Algunos capitalinos han optado por ut...
# 11  \nUna joya que todavía debe pulirse, así es Di...
# 12  Ante el desabasto de combustible en algunas ci...
# 13   Toggle navigation  SuscripcionesEl Universal ...
# 14   0 % PULSO SOCIAL0 La humanidad no sería lo qu...
#
#                                                 title  \
# 10  Ante desabasto de gasolina, capitalinos optan ...
# 11      ¿Por qué tanto alboroto en España por Lainez?
# 12                          Tips que ahorran gasolina
# 13                                                NaN
# 14                                                NaN
#
#                                                   url
# 10  http://eluniversal.com.mx/metropoli/cdmx/ante-...
# 11  http://eluniversal.com.mx/universal-deportes/f...
# 12  http://www.unionpuebla.mx/articulo/2019/01/10/...
# 13  http://www.clubeluniversal.mx/content/suscripc...
# 14  http://de10.com.mx/top-10/2019/01/12/10-de-las...

# %%
el_universal.iloc[9]['title']
# Out:
# 'En mensaje a la nación, AMLO pide apoyo para combatir huachicoleo'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0    \n[email protected]\n\nTrabajadores contratado...
# 1    \nSi eres de las personas que se 'sube al tren...
# 2    \nLuego de publicar un tuit en su cuenta perso...
# 3    \n[email protected]\n\nLa Secretaría de Movili...
# 4    \nLa jefa de Gobierno, Claudia Sheinbaum, afir...
# Name: body, dtype: object

# %%
el_universal.loc[:, 'body': 'title']
# Out:
#                                                   body  \
# 0    \n[email protected]\n\nTrabajadores contratado...
# 1    \nSi eres de las personas que se 'sube al tren...
# 2    \nLuego de publicar un tuit en su cuenta perso...
# 3    \n[email protected]\n\nLa Secretaría de Movili...
# 4    \nLa jefa de Gobierno, Claudia Sheinbaum, afir...
# ..                                                 ...
# 135  \nDiego Armando Maradona fue operado en la clí...
# 136  El gobierno de la Ciudad de México informó a t...
# 137  ¿Quieres viajar más, pero también ahorrar lo m...
# 138  Vas caminando tranquilamente en tu casa, desca...
# 139   7 % PULSO SOCIAL2 Esta mujer de ojos verdes f...
#
#                                                  title
# 0    INBA posterga incertidumbre de empleados con u...
# 1    Conoce las propiedades de la moringa, el super...
# 2    Si México, la tendencia en redes que desató Qu...
# 3    Pondrán a infractores de CDMX a pintar calles ...
# 4    Transporte público está garantizado, dice Shei...
# ..                                                 ...
# 135                   Operan a Diego Armando Maradona
# 136   Hay vacantes de promotores educativos de PILARES
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
# [140 rows x 2 columns]

# %% [markdown]
# # Data wragling

# %%
# Añadir el newspaper_uid al DataFrame

el_universal['newspaper_id'] = 'el_universal'

el_universal
# Out:
#                                                   body  \
# 0    \n[email protected]\n\nEn casas, bodegas, cent...
# 1    \nMuchas personas tienen el sueño de trabajar ...
# 2    \nMonterrey.- Jaime Rodríguez Calderón ofreció...
# 3    \nJorge Sánchez, exdirector del Instituto Mexi...
# 4    El juego del muelle es un juego de tipo sexual...
# ..                                                 ...
# 139  \nBuenos Aires.— El Cruz Azul por fin dio el s...
# 140  \nTodo parece indicar que la novela de Nicolás...
# 141   Toggle navigation  SuscripcionesEl Universal ...
# 142  Miley Cyrus fue captada saliendo de la mansión...
# 143  \n¿Imaginas poder perder hasta 3 kilos en 3 dí...
#
#                                                  title  newspaper_id
# 0    ¿Cómo opera el huachicol dentro y fuera de Pemex?  el_universal
# 1              Programas para buscar empleos en Canadá  el_universal
# 2    "El Bronco" ofrece disculpas por incidente de ...  el_universal
# 3    "Fernando Luján era profesional, disciplinado ...  el_universal
# 4                                                  NaN  el_universal
# ..                                                 ...           ...
# 139  Cruz Azul ya aceptó propuesta por Marcone: Ang...  el_universal
# 140     Nico Castillo ya está arreglado con el América  el_universal
# 141                                                NaN  el_universal
# 142                                                NaN  el_universal
# 143                Dieta del aguacate para perder peso  el_universal
#
# [144 rows x 3 columns]

# %% [markdown]
# el_universal['hosts'].value_counts()
#
# Cuenta por host en la columna de hosts

# %%
from urllib.parse import urlparse

el_universal['hosts'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                   body  \
# 0    \n[email protected]\n\nTrabajadores contratado...
# 1    \nSi eres de las personas que se 'sube al tren...
# 2    \nLuego de publicar un tuit en su cuenta perso...
# 3    \n[email protected]\n\nLa Secretaría de Movili...
# 4    \nLa jefa de Gobierno, Claudia Sheinbaum, afir...
# ..                                                 ...
# 135  \nDiego Armando Maradona fue operado en la clí...
# 136  El gobierno de la Ciudad de México informó a t...
# 137  ¿Quieres viajar más, pero también ahorrar lo m...
# 138  Vas caminando tranquilamente en tu casa, desca...
# 139   7 % PULSO SOCIAL2 Esta mujer de ojos verdes f...
#
#                                                  title  \
# 0    INBA posterga incertidumbre de empleados con u...
# 1    Conoce las propiedades de la moringa, el super...
# 2    Si México, la tendencia en redes que desató Qu...
# 3    Pondrán a infractores de CDMX a pintar calles ...
# 4    Transporte público está garantizado, dice Shei...
# ..                                                 ...
# 135                   Operan a Diego Armando Maradona
# 136   Hay vacantes de promotores educativos de PILARES
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
#                                                    url                host  \
# 0    http://eluniversal.com.mx/cultura/inba-posterg...  eluniversal.com.mx
# 1    http://eluniversal.com.mx/menu/conoce-las-prop...  eluniversal.com.mx
# 2    http://eluniversal.com.mx/nacion/sociedad/si-m...  eluniversal.com.mx
# 3    http://eluniversal.com.mx/metropoli/cdmx/pondr...  eluniversal.com.mx
# 4    http://eluniversal.com.mx/metropoli/cdmx/trans...  eluniversal.com.mx
# ..                                                 ...                 ...
# 135  http://eluniversal.com.mx/universal-deportes/f...  eluniversal.com.mx
# 136  http://www.unioncdmx.mx/articulo/2019/01/10/ed...    www.unioncdmx.mx
# 137  http://www.viveusa.mx/compras/apps-y-herramien...      www.viveusa.mx
# 138  http://www.elbotiquin.mx/medicina-general/deci...   www.elbotiquin.mx
# 139  http://de10.com.mx/top-10/2019/01/12/kirstie-a...         de10.com.mx
#
#                   hosts
# 0    eluniversal.com.mx
# 1    eluniversal.com.mx
# 2    eluniversal.com.mx
# 3    eluniversal.com.mx
# 4    eluniversal.com.mx
# ..                  ...
# 135  eluniversal.com.mx
# 136    www.unioncdmx.mx
# 137      www.viveusa.mx
# 138   www.elbotiquin.mx
# 139         de10.com.mx
#
# [140 rows x 5 columns]

# %%
el_universal['hosts'].value_counts()
# Out:
# eluniversal.com.mx            55
# www.eluniversal.com.mx        29
# www.viveusa.mx                 9
# www.elbotiquin.mx              9
# sanluis.eluniversal.com.mx     5
#                               ..
# www.unionguanajuato.mx         2
# www.unionyucatan.mx            2
# www.unionedomex.mx             2
# www.unioncdmx.mx               2
# www.clubeluniversal.mx         1
# Name: hosts, Length: 16, dtype: int64

# %%
# Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

missing_titles = (el_universal[missing_titles_mask]['url']
        .str.extract(r'(?P<missing_titles>[^/]+)$')
        .applymap(lambda title: title.split('-'))
        .applymap(lambda title_word_list: ' '.join(title_word_list))
    )

missing_titles
#missing_titles_mask.value_counts()
# Out:
#                                         missing_titles
# 6    mexico seria potencia sin oaxaca guerrero y ch...
# 7    kendall jenner enciende instagram con sesion e...
# 13                                       suscripciones
# 14   10 de las edificaciones mas antiguas sobre la ...
# 17    adolescente vende rinon para comprarse un iphone
# ..                                                 ...
# 127  estos son los precios de las visas de eu para ...
# 128                        hace dano comer mucho huevo
# 137  apps y herramientas que te ayudaran encontrar ...
# 138           decir groserias puede controlar el dolor
# 139  kirstie alley tal vez la recuerden por mira qu...
#
# [28 rows x 1 columns]

# %%
import pandas as pd

pd.options.display.max_rows = 10
el_universal = pd.read_csv('eluniversal_2019_01_12_articles.csv')

el_universal

# el_universal.tail() | para los últimos cinco
# el_universal.head() | para los primeros cinco
# Out:
#                                                   body  \
# 0    \n[email protected]\n\nTrabajadores contratado...
# 1    \nSi eres de las personas que se 'sube al tren...
# 2    \nLuego de publicar un tuit en su cuenta perso...
# 3    \n[email protected]\n\nLa Secretaría de Movili...
# 4    \nLa jefa de Gobierno, Claudia Sheinbaum, afir...
# ..                                                 ...
# 135  \nDiego Armando Maradona fue operado en la clí...
# 136  El gobierno de la Ciudad de México informó a t...
# 137  ¿Quieres viajar más, pero también ahorrar lo m...
# 138  Vas caminando tranquilamente en tu casa, desca...
# 139   7 % PULSO SOCIAL2 Esta mujer de ojos verdes f...
#
#                                                  title  \
# 0    INBA posterga incertidumbre de empleados con u...
# 1    Conoce las propiedades de la moringa, el super...
# 2    Si México, la tendencia en redes que desató Qu...
# 3    Pondrán a infractores de CDMX a pintar calles ...
# 4    Transporte público está garantizado, dice Shei...
# ..                                                 ...
# 135                   Operan a Diego Armando Maradona
# 136   Hay vacantes de promotores educativos de PILARES
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
#                                                    url
# 0    http://eluniversal.com.mx/cultura/inba-posterg...
# 1    http://eluniversal.com.mx/menu/conoce-las-prop...
# 2    http://eluniversal.com.mx/nacion/sociedad/si-m...
# 3    http://eluniversal.com.mx/metropoli/cdmx/pondr...
# 4    http://eluniversal.com.mx/metropoli/cdmx/trans...
# ..                                                 ...
# 135  http://eluniversal.com.mx/universal-deportes/f...
# 136  http://www.unioncdmx.mx/articulo/2019/01/10/ed...
# 137  http://www.viveusa.mx/compras/apps-y-herramien...
# 138  http://www.elbotiquin.mx/medicina-general/deci...
# 139  http://de10.com.mx/top-10/2019/01/12/kirstie-a...
#
# [140 rows x 3 columns]

# %%
# Añadir uids a las filas
# axis = 1 (son filas)
# axis = 0 (son columnas)

import hashlib

uids = (el_universal
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
       )

el_universal['uid'] = uids
el_universal.set_index('uid', inplace=True)

el_universal
# Out:
#                                                                                body  \
# uid
# 52fe742556bf4a5a3e95ba817d694577  \n[email protected]\n\nTrabajadores contratado...
# e5371a73bd61e195e678fc7ed1601aca  \nSi eres de las personas que se 'sube al tren...
# 81a34d60bde57c70f55189d3323e88db  \nLuego de publicar un tuit en su cuenta perso...
# defb6e8da9ddb1578de73483a0eb0517  \n[email protected]\n\nLa Secretaría de Movili...
# 0eb09c1fe98a8bb236b91e6371135934  \nLa jefa de Gobierno, Claudia Sheinbaum, afir...
# ...                                                                             ...
# f91803b517b2f1a4209483e568508634  \nDiego Armando Maradona fue operado en la clí...
# 5194eb23e5c12fd125fcf402ccd2599b  El gobierno de la Ciudad de México informó a t...
# 863acbd77bfa505a91b6efebd0e78c6d  ¿Quieres viajar más, pero también ahorrar lo m...
# 701200c560839cbcb72f1a87610dd844  Vas caminando tranquilamente en tu casa, desca...
# c218aeddc05811feca04b21412164234   7 % PULSO SOCIAL2 Esta mujer de ojos verdes f...
#
#                                                                               title  \
# uid
# 52fe742556bf4a5a3e95ba817d694577  INBA posterga incertidumbre de empleados con u...
# e5371a73bd61e195e678fc7ed1601aca  Conoce las propiedades de la moringa, el super...
# 81a34d60bde57c70f55189d3323e88db  Si México, la tendencia en redes que desató Qu...
# defb6e8da9ddb1578de73483a0eb0517  Pondrán a infractores de CDMX a pintar calles ...
# 0eb09c1fe98a8bb236b91e6371135934  Transporte público está garantizado, dice Shei...
# ...                                                                             ...
# f91803b517b2f1a4209483e568508634                   Operan a Diego Armando Maradona
# 5194eb23e5c12fd125fcf402ccd2599b   Hay vacantes de promotores educativos de PILARES
# 863acbd77bfa505a91b6efebd0e78c6d                                                NaN
# 701200c560839cbcb72f1a87610dd844                                                NaN
# c218aeddc05811feca04b21412164234                                                NaN
#
#                                                                                 url
# uid
# 52fe742556bf4a5a3e95ba817d694577  http://eluniversal.com.mx/cultura/inba-posterg...
# e5371a73bd61e195e678fc7ed1601aca  http://eluniversal.com.mx/menu/conoce-las-prop...
# 81a34d60bde57c70f55189d3323e88db  http://eluniversal.com.mx/nacion/sociedad/si-m...
# defb6e8da9ddb1578de73483a0eb0517  http://eluniversal.com.mx/metropoli/cdmx/pondr...
# 0eb09c1fe98a8bb236b91e6371135934  http://eluniversal.com.mx/metropoli/cdmx/trans...
# ...                                                                             ...
# f91803b517b2f1a4209483e568508634  http://eluniversal.com.mx/universal-deportes/f...
# 5194eb23e5c12fd125fcf402ccd2599b  http://www.unioncdmx.mx/articulo/2019/01/10/ed...
# 863acbd77bfa505a91b6efebd0e78c6d  http://www.viveusa.mx/compras/apps-y-herramien...
# 701200c560839cbcb72f1a87610dd844  http://www.elbotiquin.mx/medicina-general/deci...
# c218aeddc05811feca04b21412164234  http://de10.com.mx/top-10/2019/01/12/kirstie-a...
#
# [140 rows x 3 columns]

# %%
strippbody = (el_universal
                  .apply(lambda row: row['body'], axis=1)
                  .apply(lambda body: list(body))
                  .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                  .apply(lambda letters: ''.join(letters))
)

el_universal['body'] = strippbody

el_universal
# Out:
#                                                   body  \
# 0    [email protected]Trabajadores contratados bajo...
# 1    Si eres de las personas que se 'sube al tren d...
# 2    Luego de publicar un tuit en su cuenta persona...
# 3    [email protected]La Secretaría de Movilidad de...
# 4    La jefa de Gobierno, Claudia Sheinbaum, afirmó...
# ..                                                 ...
# 135  Diego Armando Maradona fue operado en la clíni...
# 136  El gobierno de la Ciudad de México informó a t...
# 137  ¿Quieres viajar más, pero también ahorrar lo m...
# 138  Vas caminando tranquilamente en tu casa, desca...
# 139   7 % PULSO SOCIAL2 Esta mujer de ojos verdes f...
#
#                                                  title  \
# 0    INBA posterga incertidumbre de empleados con u...
# 1    Conoce las propiedades de la moringa, el super...
# 2    Si México, la tendencia en redes que desató Qu...
# 3    Pondrán a infractores de CDMX a pintar calles ...
# 4    Transporte público está garantizado, dice Shei...
# ..                                                 ...
# 135                   Operan a Diego Armando Maradona
# 136   Hay vacantes de promotores educativos de PILARES
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
#                                                    url  n_tokens_title
# 0    http://eluniversal.com.mx/cultura/inba-posterg...             6.0
# 1    http://eluniversal.com.mx/menu/conoce-las-prop...             5.0
# 2    http://eluniversal.com.mx/nacion/sociedad/si-m...             6.0
# 3    http://eluniversal.com.mx/metropoli/cdmx/pondr...             8.0
# 4    http://eluniversal.com.mx/metropoli/cdmx/trans...             7.0
# ..                                                 ...             ...
# 135  http://eluniversal.com.mx/universal-deportes/f...             4.0
# 136  http://www.unioncdmx.mx/articulo/2019/01/10/ed...             4.0
# 137  http://www.viveusa.mx/compras/apps-y-herramien...             NaN
# 138  http://www.elbotiquin.mx/medicina-general/deci...             NaN
# 139  http://de10.com.mx/top-10/2019/01/12/kirstie-a...             NaN
#
# [140 rows x 4 columns]

# %% [markdown]
# # TOKENIZANDO

# %%
import nltk
from nltk.corpus import stopwords

#nltk.download('punkt')
#nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
                .dropna()
                .apply(lambda row: nltk.word_tokenize(row[column_name]), axis = 1)
                .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
                .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
                .apply(lambda valid_word_list: len(valid_word_list))
           )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')

el_universal
# Out:
#                                                   body  \
# 0    [email protected]Trabajadores contratados bajo...
# 1    Si eres de las personas que se 'sube al tren d...
# 2    Luego de publicar un tuit en su cuenta persona...
# 3    [email protected]La Secretaría de Movilidad de...
# 4    La jefa de Gobierno, Claudia Sheinbaum, afirmó...
# ..                                                 ...
# 135  Diego Armando Maradona fue operado en la clíni...
# 136  El gobierno de la Ciudad de México informó a t...
# 137  ¿Quieres viajar más, pero también ahorrar lo m...
# 138  Vas caminando tranquilamente en tu casa, desca...
# 139   7 % PULSO SOCIAL2 Esta mujer de ojos verdes f...
#
#                                                  title  \
# 0    INBA posterga incertidumbre de empleados con u...
# 1    Conoce las propiedades de la moringa, el super...
# 2    Si México, la tendencia en redes que desató Qu...
# 3    Pondrán a infractores de CDMX a pintar calles ...
# 4    Transporte público está garantizado, dice Shei...
# ..                                                 ...
# 135                   Operan a Diego Armando Maradona
# 136   Hay vacantes de promotores educativos de PILARES
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
#
#                                                    url  n_tokens_title
# 0    http://eluniversal.com.mx/cultura/inba-posterg...             6.0
# 1    http://eluniversal.com.mx/menu/conoce-las-prop...             5.0
# 2    http://eluniversal.com.mx/nacion/sociedad/si-m...             6.0
# 3    http://eluniversal.com.mx/metropoli/cdmx/pondr...             8.0
# 4    http://eluniversal.com.mx/metropoli/cdmx/trans...             7.0
# ..                                                 ...             ...
# 135  http://eluniversal.com.mx/universal-deportes/f...             4.0
# 136  http://www.unioncdmx.mx/articulo/2019/01/10/ed...             4.0
# 137  http://www.viveusa.mx/compras/apps-y-herramien...             NaN
# 138  http://www.elbotiquin.mx/medicina-general/deci...             NaN
# 139  http://de10.com.mx/top-10/2019/01/12/kirstie-a...             NaN
#
# [140 rows x 4 columns]
